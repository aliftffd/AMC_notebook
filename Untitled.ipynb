# %%
import os 
import sys

module_path = os.path.abspath(os.path.join('/home/lipplopp/Documents/research/notebook/test_'))
sys.path.insert(0,module_path)

# %%
from multiple_two_diffrentsource import multiple_two_diffrentsource

tb = multiple_two_diffrentsource()
tb.start()
import time; time.sleep(1)
tb.stop(); tb.wait()

samples = tb.vector_sink.data()

import matplotlib.pyplot as plt
plt.plot(samples)
plt.title("Multiplied Signal Output")
plt.xlabel("Sample Index")
plt.ylabel("Amplitude")
plt.grid(True)
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
